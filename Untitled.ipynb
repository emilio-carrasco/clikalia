# %%
import pandas as pd

# %%
pd.read_csv('./data/web.csv', sep=';')
# Out:
#                  uv estado tipo_vivienda    precio  precio_antiguo  descuento  \
# 0    UV/2020/000003      1          Piso  160000.0             0.0        0.0
# 1    UV/2020/000004      1          Piso  125000.0             0.0        0.0
# 2    UV/2020/000006      1          Piso       0.0             0.0        0.0
# 3    UV/2020/000007      1          Piso  159000.0             0.0        0.0
# 4    UV/2020/000008      1          Piso  170000.0             0.0        0.0
# ..              ...    ...           ...       ...             ...        ...
# 185  UV/2021/000392      1          Piso  139900.0        149000.0        6.0
# 186  UV/2021/000411      1          Piso  235000.0             0.0        0.0
# 187  UV/2021/000426      1          Piso  148000.0             0.0        0.0
# 188  UV/2021/000433      1          Piso  300000.0             0.0        0.0
# 189  UV/2021/000441      1          Piso  237000.0             0.0        0.0
#
#     moneda  gastos_comunitarios
# ...
